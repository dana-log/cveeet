# %%
import pandas as pd
covid_data = pd.read_csv('/home/dana/ide/project_0/data/covid_data.csv')
covid_data.head()
# Out:
#          date province/state country  confirmed  deaths  recovered
# 0  01/22/2020          Anhui   China        1.0     0.0        0.0
# 1  01/22/2020        Beijing   China       14.0     0.0        0.0
# 2  01/22/2020      Chongqing   China        6.0     0.0        0.0
# 3  01/22/2020         Fujian   China        1.0     0.0        0.0
# 4  01/22/2020          Gansu   China        0.0     0.0        0.0

# %%
vaccinations_data = pd.read_csv('/home/dana/ide/project_0/data/country_vaccinations.csv')
vaccinations_data = vaccinations_data[
    ['country', 'date', 'total_vaccinations', 
     'people_vaccinated', 'people_vaccinated_per_hundred',
     'people_fully_vaccinated', 'people_fully_vaccinated_per_hundred',
     'daily_vaccinations', 'vaccines']
]

# %%
covid_data = covid_data.groupby(
    ['date', 'country'], 
    as_index=False
)[['confirmed', 'deaths', 'recovered']].sum()

covid_data['date'] = pd.to_datetime(covid_data['date'])

covid_data['active'] = covid_data['confirmed'] - covid_data['deaths'] - covid_data['recovered']

covid_data = covid_data.sort_values(by=['country','date'])
covid_data['daily_confirmed'] = covid_data.groupby('country')['confirmed'].diff()
covid_data['daily_deaths'] = covid_data.groupby('country')['deaths'].diff()
covid_data['daily_recovered'] = covid_data.groupby('country')['recovered'].diff()

vaccinations_data['date'] = pd.to_datetime(vaccinations_data['date'])

covid_data.head()
# Out:
#            date      country  confirmed  deaths  recovered  active  \
# 881  2020-02-24  Afghanistan        1.0     0.0        0.0     1.0
# 920  2020-02-25  Afghanistan        1.0     0.0        0.0     1.0
# 963  2020-02-26  Afghanistan        1.0     0.0        0.0     1.0
# 1013 2020-02-27  Afghanistan        1.0     0.0        0.0     1.0
# 1067 2020-02-28  Afghanistan        1.0     0.0        0.0     1.0
#
#       daily_confirmed  daily_deaths  daily_recovered
# 881               NaN           NaN              NaN
# 920               0.0           0.0              0.0
# 963               0.0           0.0              0.0
# 1013              0.0           0.0              0.0
# 1067              0.0           0.0              0.0
